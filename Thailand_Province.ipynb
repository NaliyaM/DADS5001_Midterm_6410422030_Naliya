# %%
import numpy as np
import pandas as pd

# %%
ThaiDF = pd.read_csv("https://data.go.th/dataset/3aa027e3-5485-4da2-89b0-b399fab019a0/resource/6d6b911a-df77-4044-8ce9-baf35d646d7c/download/25640531_sc002_.csv")
ThaiDF.head(20)
# Out:
#     ProvinceNo  ProvinceMOI_ID   ProvinceNameThai Region_VaccineRollout_MOPH  \
# 0            1              10      กรุงเทพมหานคร    กรุงเทพมหานครและปริมณฑล
# 1            2              81      จังหวัดกระบี่                     ภาคใต้
# 2            3              71   จังหวัดกาญจนบุรี                 ภาคตะวันตก
# 3            4              46   จังหวัดกาฬสินธุ์      ภาคตะวันออกเฉียงเหนือ
# 4            5              62   จังหวัดกำแพงเพชร                    ภาคกลาง
# 5            6              40     จังหวัดขอนแก่น      ภาคตะวันออกเฉียงเหนือ
# 6            7              22    จังหวัดจันทบุรี                ภาคตะวันออก
# 7            8              24  จังหวัดฉะเชิงเทรา                ภาคตะวันออก
# 8            9              20      จังหวัดชลบุรี                ภาคตะวันออก
# 9           10              18      จังหวัดชัยนาท                    ภาคกลาง
# 10          11              36     จังหวัดชัยภูมิ      ภาคตะวันออกเฉียงเหนือ
# ...

# %%
ThaiDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Columns: 112 entries, ProvinceNo to Region_COVIDCaseReport
# dtypes: int64(4), object(108)
# memory usage: 67.5+ KB

# %%
ThaiDF.columns
# Out:
# Index(['ProvinceNo', 'ProvinceMOI_ID', 'ProvinceNameThai',
#        'Region_VaccineRollout_MOPH', 'Region_RDPB', 'Region_RedCrossChapter',
#        'Region_SenatorFieldWork', 'Region_JFO', 'Region_TCGOffice', 'RegionID',
#        ...
#        'Region_ThailandPost', 'Region_OccupationalSafety',
#        'Region_PrimaryIndustry_Mineral', 'Region_NACC',
#        'Region_ProvincialLabourOffice', 'Region_NFC', 'Region_Treasury',
#        'Region_Probation', 'Region_FRDFund', 'Region_COVIDCaseReport'],
#       dtype='object', length=112)

# %%
Thai_Region = ThaiDF.loc[:, ["ProvinceMOI_ID","ProvinceNameThai","RegionID","RegionName"]]
Thai_Region.head(20)
# Out:
#     ProvinceMOI_ID   ProvinceNameThai  RegionID             RegionName
# 0               10      กรุงเทพมหานคร         7               ส่วนกลาง
# 1               81      จังหวัดกระบี่         2                 ภาคใต้
# 2               71   จังหวัดกาญจนบุรี         1                ภาคกลาง
# 3               46   จังหวัดกาฬสินธุ์         5  ภาคตะวันออกเฉียงเหนือ
# 4               62   จังหวัดกำแพงเพชร         6               ภาคเหนือ
# 5               40     จังหวัดขอนแก่น         5  ภาคตะวันออกเฉียงเหนือ
# 6               22    จังหวัดจันทบุรี         4            ภาคตะวันออก
# 7               24  จังหวัดฉะเชิงเทรา         4            ภาคตะวันออก
# 8               20      จังหวัดชลบุรี         4            ภาคตะวันออก
# 9               18      จังหวัดชัยนาท         1                ภาคกลาง
# 10              36     จังหวัดชัยภูมิ         5  ภาคตะวันออกเฉียงเหนือ
# 11              86       จังหวัดชุมพร         2                 ภาคใต้
# ...

# %%
Thai_Region["ProvinceNameThai"] = Thai_Region["ProvinceNameThai"].str.replace("จังหวัด","")
Thai_Region.head(20)
# Out:
#     ProvinceMOI_ID ProvinceNameThai  RegionID             RegionName
# 0               10    กรุงเทพมหานคร         7               ส่วนกลาง
# 1               81           กระบี่         2                 ภาคใต้
# 2               71        กาญจนบุรี         1                ภาคกลาง
# 3               46        กาฬสินธุ์         5  ภาคตะวันออกเฉียงเหนือ
# 4               62        กำแพงเพชร         6               ภาคเหนือ
# 5               40          ขอนแก่น         5  ภาคตะวันออกเฉียงเหนือ
# 6               22         จันทบุรี         4            ภาคตะวันออก
# 7               24       ฉะเชิงเทรา         4            ภาคตะวันออก
# 8               20           ชลบุรี         4            ภาคตะวันออก
# 9               18           ชัยนาท         1                ภาคกลาง
# 10              36          ชัยภูมิ         5  ภาคตะวันออกเฉียงเหนือ
# 11              86            ชุมพร         2                 ภาคใต้
# 12              57         เชียงราย         6               ภาคเหนือ
# ...

# %%
Thai_Region["ProvinceNameThai"].values
# Out:
# array(['กรุงเทพมหานคร', 'กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร',
#        'ขอนแก่น', 'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ',
#        'ชุมพร', 'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...
